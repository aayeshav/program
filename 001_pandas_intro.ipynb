# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('movies.csv')
# Out:
#      Rank                         Title           Studio       Gross  Year
# 0       1             Avengers: Endgame      Buena Vista  $2,796.30   2019
# 1       2                        Avatar              Fox  $2,789.70   2009
# 2       3                       Titanic        Paramount  $2,187.50   1997
# 3       4  Star Wars: The Force Awakens      Buena Vista  $2,068.20   2015
# 4       5        Avengers: Infinity War      Buena Vista  $2,048.40   2018
# ..    ...                           ...              ...         ...   ...
# 777   778                     Yogi Bear  Warner Brothers    $201.60   2010
# 778   779           Garfield: The Movie              Fox    $200.80   2004
# 779   780                   Cats & Dogs  Warner Brothers    $200.70   2001
# 780   781      The Hunt for Red October        Paramount    $200.50   1990
# 781   782                      Valkyrie              MGM    $200.30   2008
#
# [782 rows x 5 columns]

# %%
movies=pd.read_csv('movies.csv')
print(type(movies))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
movies = pd.read_csv('movies.csv', index_col='Title')
print(movies)
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
movies.head()  #display first 5 row of dataframe
# Out:
#                               Rank       Studio       Gross  Year
# Title
# Avengers: Endgame                1  Buena Vista  $2,796.30   2019
# Avatar                           2          Fox  $2,789.70   2009
# Titanic                          3    Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4  Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5  Buena Vista  $2,048.40   2018

# %%
movies.head(10) #display first 10 row of dataframe
# Out:
#                               Rank       Studio       Gross  Year
# Title
# Avengers: Endgame                1  Buena Vista  $2,796.30   2019
# Avatar                           2          Fox  $2,789.70   2009
# Titanic                          3    Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4  Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5  Buena Vista  $2,048.40   2018
# Jurassic World                   6    Universal  $1,671.70   2015
# Marvel's The Avengers            7  Buena Vista  $1,518.80   2012
# Furious 7                        8    Universal  $1,516.00   2015
# Avengers: Age of Ultron          9  Buena Vista  $1,405.40   2015
# Black Panther                   10  Buena Vista  $1,346.90   2018

# %%
movies.tail() #display last 5 row of dataframe
# Out:
#                           Rank           Studio     Gross  Year
# Title
# Yogi Bear                  778  Warner Brothers  $201.60   2010
# Garfield: The Movie        779              Fox  $200.80   2004
# Cats & Dogs                780  Warner Brothers  $200.70   2001
# The Hunt for Red October   781        Paramount  $200.50   1990
# Valkyrie                   782              MGM  $200.30   2008

# %%
movies.tail(15) #display last 15 row of dataframe
# Out:
#                               Rank           Studio     Gross  Year
# Title
# Arrival                        768        Paramount  $203.40   2016
# Need for Speed                 769      Buena Vista  $203.30   2014
# Hairspray                      770         New Line  $202.50   2007
# Ponyo                          771      Buena Vista  $202.40   2009
# Patch Adams                    772        Universal  $202.30   1998
# Fun with Dick and Jane         773             Sony  $202.00   2005
# Teenage Mutant Ninja Turtles   774         New Line  $202.00   1990
# Kindergarten Cop               775        Universal  $202.00   1990
# Straight Outta Compton         776        Universal  $201.60   2015
# 21 Jump Street                 777             Sony  $201.60   2012
# Yogi Bear                      778  Warner Brothers  $201.60   2010
# Garfield: The Movie            779              Fox  $200.80   2004
# Cats & Dogs                    780  Warner Brothers  $200.70   2001
# ...

# %%
len(movies)  #number of rows in dataframe
# Out:
# 782

# %%
movies.shape  #number of rows and columns in dataframe
# Out:
# (782, 4)

# %%
movies.size   #total number of elements in dataframe
# Out:
# 3128

# %%
movies.dtypes  #data types of each column in dataframe
# Out:
# Rank       int64
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
movies.iloc[767] #access row by integer location
# Out:
# Rank            768
# Studio    Paramount
# Gross      $203.40
# Year           2016
# Name: Arrival, dtype: object

# %%
movies.loc["Yogi Bear"] #access row by index label
# Out:
# Rank                  778
# Studio    Warner Brothers
# Gross            $201.60
# Year                 2010
# Name: Yogi Bear, dtype: object

# %%
movies.loc["Straight Outta Compton"] #access row by index label
# Out:
# Rank            776
# Studio    Universal
# Gross      $201.60
# Year           2015
# Name: Straight Outta Compton, dtype: object

# %%
movies
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
movies.sort_values(by="Year",ascending=False) #sort dataframe by Year column in descending order
# Out:
#                                    Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                     1      Buena Vista  $2,796.30   2019
# Godzilla: King of the Monsters      315  Warner Brothers    $378.10   2019
# Shazam!                             340  Warner Brothers    $364.10   2019
# John Wick: Chapter 3 - Parabellum   458        Lionsgate    $304.70   2019
# Dumbo                               369      Buena Vista    $351.80   2019
# ...                                 ...              ...         ...   ...
# The Godfather                       604        Paramount    $245.10   1972
# The Jungle Book                     755      Buena Vista    $205.80   1967
# 101 Dalmatians                      708      Buena Vista    $215.90   1961
# Bambi                               540              RKO    $267.40   1942
# Gone with the Wind                  288              MGM    $402.40   1939
#
# [782 rows x 4 columns]

# %%
movies.sort_values(by="Year", ascending=False).head(10) #sort by year in descending order and display first 10 rows
# Out:
#                                    Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                     1      Buena Vista  $2,796.30   2019
# Godzilla: King of the Monsters      315  Warner Brothers    $378.10   2019
# Shazam!                             340  Warner Brothers    $364.10   2019
# John Wick: Chapter 3 - Parabellum   458        Lionsgate    $304.70   2019
# Dumbo                               369      Buena Vista    $351.80   2019
# Alita: Battle Angel                 286              Fox    $404.90   2019
# Captain Marvel                       22      Buena Vista  $1,128.30   2019
# Men in Black International          686             Sony    $220.80   2019
# The Secret Life of Pets 2           670        Universal    $225.90   2019
# Pokemon Detective Pikachu           263  Warner Brothers    $427.50   2019

# %%
movies.sort_values(by=["Studio","Year"], ascending=[True, False]) #sort by Studio and Year in ascending and descending order respectively
# Out:
#                          Rank       Studio       Gross  Year
# Title
# The Blair Witch Project   588      Artisan    $248.60   1999
# Avengers: Endgame           1  Buena Vista  $2,796.30   2019
# Captain Marvel             22  Buena Vista  $1,128.30   2019
# Aladdin                    59  Buena Vista    $880.20   2019
# Toy Story 4               198  Buena Vista    $519.80   2019
# ...                       ...          ...         ...   ...
# The Intouchables          265    Weinstein    $426.60   2012
# Django Unchained          266    Weinstein    $425.40   2012
# Silver Linings Playbook   631    Weinstein    $236.40   2012
# The King's Speech         276    Weinstein    $414.20   2010
# Inglourious Basterds      424    Weinstein    $321.50   2009
#
# [782 rows x 4 columns]

# %%
movies
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
movies.sort_index().head(30) #sort dataframe by index and display first 30 rows
# Out:
#                                       Rank           Studio       Gross  Year
# Title
# 10,000 B.C.                            536  Warner Brothers    $269.80   2008
# 101 Dalmatians                         708      Buena Vista    $215.90   1961
# 101 Dalmatians                         425      Buena Vista    $320.70   1996
# 2 Fast 2 Furious                       632        Universal    $236.40   2003
# 2012                                    93             Sony    $769.70   2009
# 21 Jump Street                         777             Sony    $201.60   2012
# 22 Jump Street                         407             Sony    $331.30   2014
# 300                                    242  Warner Brothers    $456.10   2007
# 300: Rise of An Empire                 394  Warner Brothers    $337.60   2014
# 8 Mile                                 612        Universal    $242.90   2002
# A Beautiful Mind                       437        Universal    $313.50   2001
# ...

# %%
movies["Studio"] #access Studio column
# Out:
# Title
# Avengers: Endgame                   Buena Vista
# Avatar                                      Fox
# Titanic                               Paramount
# Star Wars: The Force Awakens        Buena Vista
# Avengers: Infinity War              Buena Vista
#                                      ...
# Yogi Bear                       Warner Brothers
# Garfield: The Movie                         Fox
# Cats & Dogs                     Warner Brothers
# The Hunt for Red October              Paramount
# Valkyrie                                    MGM
# Name: Studio, Length: 782, dtype: object

# %%
type(movies["Rank"]) #access Rank column as a Series
# Out:
# pandas.core.series.Series

# %%
movies["Studio"].value_counts().head(20)
# Out:
# Studio
# Warner Brothers    132
# Buena Vista        125
# Fox                117
# Universal          109
# Sony                86
# Paramount           76
# Dreamworks          27
# Lionsgate           21
# New Line            16
# MGM                 11
# TriStar             11
# Miramax             10
# Weinstein            6
# Columbia             5
# WGUSA                4
# SonR                 2
# Orion                2
# Polygram             2
# Dimension            2
# HC                   1
# Name: count, dtype: int64

# %%
movies["Studio"]=="Warner Brothers" #boolean mask for Studio column
# Out:
# Title
# Avengers: Endgame               False
# Avatar                          False
# Titanic                         False
# Star Wars: The Force Awakens    False
# Avengers: Infinity War          False
#                                 ...
# Yogi Bear                        True
# Garfield: The Movie             False
# Cats & Dogs                      True
# The Hunt for Red October        False
# Valkyrie                        False
# Name: Studio, Length: 782, dtype: bool

# %%
movies[movies["Studio"]=="Warner Brothers"] #filter rows where Studio is "Warner Brothers"
# Out:
#                                              Rank           Studio  \
# Title
# Harry Potter and the Deathly Hallows Part 2    11  Warner Brothers
# Aquaman                                        21  Warner Brothers
# The Dark Knight Rises                          27  Warner Brothers
# The Hobbit: An Unexpected Journey              38  Warner Brothers
# The Dark Knight                                39  Warner Brothers
# ...                                           ...              ...
# Horrible Bosses                               743  Warner Brothers
# Me Before You                                 747  Warner Brothers
# JFK                                           758  Warner Brothers
# Yogi Bear                                     778  Warner Brothers
# Cats & Dogs                                   780  Warner Brothers
#
#                                                   Gross  Year
# Title
# Harry Potter and the Deathly Hallows Part 2  $1,341.70   2011
# ...

# %%
released_by_universal=(movies["Studio"]=="Universal") #boolean mask for Universal Studio
movies[released_by_universal] #filter rows where Studio is "Universal"
# Out:
#                                 Rank     Studio       Gross  Year
# Title
# Jurassic World                     6  Universal  $1,671.70   2015
# Furious 7                          8  Universal  $1,516.00   2015
# Jurassic World: Fallen Kingdom    13  Universal  $1,309.50   2018
# The Fate of the Furious           17  Universal  $1,236.00   2017
# Minions                           19  Universal  $1,159.40   2015
# ...                              ...        ...         ...   ...
# The Break-Up                     763  Universal    $205.00   2006
# Everest                          766  Universal    $203.40   2015
# Patch Adams                      772  Universal    $202.30   1998
# Kindergarten Cop                 775  Universal    $202.00   1990
# Straight Outta Compton           776  Universal    $201.60   2015
#
# [109 rows x 4 columns]

# %%
released_by_universal = movies["Studio"] == "Universal" 
released_in_2015 = movies["Year"] == 2015 
movies[released_by_universal & released_in_2015]  # filter rows where Studio is "Universal" and Year is 2015
# Out:
#                         Rank     Studio       Gross  Year
# Title
# Jurassic World             6  Universal  $1,671.70   2015
# Furious 7                  8  Universal  $1,516.00   2015
# Minions                   19  Universal  $1,159.40   2015
# Fifty Shades of Grey     165  Universal    $571.00   2015
# Pitch Perfect 2          504  Universal    $287.50   2015
# Ted 2                    702  Universal    $216.70   2015
# Everest                  766  Universal    $203.40   2015
# Straight Outta Compton   776  Universal    $201.60   2015

# %%
released_by_universal = movies["Studio"] == "Universal" 
released_in_2015 = movies["Year"] == 2015 
movies[released_by_universal | released_in_2015]
# Out:
#                                 Rank       Studio       Gross  Year
# Title
# Star Wars: The Force Awakens       4  Buena Vista  $2,068.20   2015
# Jurassic World                     6    Universal  $1,671.70   2015
# Furious 7                          8    Universal  $1,516.00   2015
# Avengers: Age of Ultron            9  Buena Vista  $1,405.40   2015
# Jurassic World: Fallen Kingdom    13    Universal  $1,309.50   2018
# ...                              ...          ...         ...   ...
# The Break-Up                     763    Universal    $205.00   2006
# Everest                          766    Universal    $203.40   2015
# Patch Adams                      772    Universal    $202.30   1998
# Kindergarten Cop                 775    Universal    $202.00   1990
# Straight Outta Compton           776    Universal    $201.60   2015
#
# [140 rows x 4 columns]

# %%
before_1975=movies["Year"]<1975
movies[before_1975] #filter rows where Year is before 1975
# Out:
#                     Rank           Studio     Gross  Year
# Title
# The Exorcist         252  Warner Brothers  $441.30   1973
# Gone with the Wind   288              MGM  $402.40   1939
# Bambi                540              RKO  $267.40   1942
# The Godfather        604        Paramount  $245.10   1972
# 101 Dalmatians       708      Buena Vista  $215.90   1961
# The Jungle Book      755      Buena Vista  $205.80   1967

# %%
mid_80s=movies["Year"].between(1983,1986)
movies[mid_80s] #filter rows where Year is between 1983 and 1986
# Out:
#                                       Rank     Studio     Gross  Year
# Title
# Return of the Jedi                     222        Fox  $475.10   1983
# Back to the Future                     311  Universal  $381.10   1985
# Top Gun                                357  Paramount  $356.80   1986
# Indiana Jones and the Temple of Doom   403  Paramount  $333.10   1984
# Crocodile Dundee                       413  Paramount  $328.20   1986
# Beverly Hills Cop                      432  Paramount  $316.40   1984
# Rocky IV                               467        MGM  $300.50   1985
# Rambo: First Blood Part II             469    TriStar  $300.40   1985
# Ghostbusters                           485   Columbia  $295.20   1984
# Out of Africa                          662  Universal  $227.50   1985

# %%
movies.head(50)
# Out:
#                                                Rank           Studio  \
# Title
# Avengers: Endgame                                 1      Buena Vista
# Avatar                                            2              Fox
# Titanic                                           3        Paramount
# Star Wars: The Force Awakens                      4      Buena Vista
# Avengers: Infinity War                            5      Buena Vista
# Jurassic World                                    6        Universal
# Marvel's The Avengers                             7      Buena Vista
# Furious 7                                         8        Universal
# Avengers: Age of Ultron                           9      Buena Vista
# Black Panther                                    10      Buena Vista
# Harry Potter and the Deathly Hallows Part 2      11  Warner Brothers
# Star Wars: The Last Jedi                         12      Buena Vista
# ...

# %%
has_dark_in_title=movies.index.str.lower().str.contains("dark")
movies[has_dark_in_title] #filter rows where index contains "dark" in title
# Out:
#                                 Rank           Studio       Gross  Year
# Title
# Transformers: Dark of the Moon    23        Paramount  $1,123.80   2011
# The Dark Knight Rises             27  Warner Brothers  $1,084.90   2012
# The Dark Knight                   39  Warner Brothers  $1,004.90   2008
# Thor: The Dark World             132      Buena Vista    $644.60   2013
# Star Trek Into Darkness          232        Paramount    $467.40   2013
# Fifty Shades Darker              309        Universal    $381.50   2017
# Dark Shadows                     600  Warner Brothers    $245.50   2012
# Dark Phoenix                     603              Fox    $245.10   2019

# %%
movies.head(2)
# Out:
#                    Rank       Studio       Gross  Year
# Title
# Avengers: Endgame     1  Buena Vista  $2,796.30   2019
# Avatar                2          Fox  $2,789.70   2009

# %%
movies.dtypes
# Out:
# Rank       int64
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
movies["Gross"].str.replace("$","",regex=False).str.replace(",","",regex=False)
# Out:
# Title
# Avengers: Endgame               2796.30
# Avatar                          2789.70
# Titanic                         2187.50
# Star Wars: The Force Awakens    2068.20
# Avengers: Infinity War          2048.40
#                                   ...
# Yogi Bear                        201.60
# Garfield: The Movie              200.80
# Cats & Dogs                      200.70
# The Hunt for Red October         200.50
# Valkyrie                         200.30
# Name: Gross, Length: 782, dtype: object

# %%
(movies["Gross"].str.replace("$","",regex=False)
 .str.replace(",","",regex=False)
 .astype(float)
)  #convert Gross column to float after removing $ and , symbols
# Out:
# Title
# Avengers: Endgame               2796.3
# Avatar                          2789.7
# Titanic                         2187.5
# Star Wars: The Force Awakens    2068.2
# Avengers: Infinity War          2048.4
#                                  ...
# Yogi Bear                        201.6
# Garfield: The Movie              200.8
# Cats & Dogs                      200.7
# The Hunt for Red October         200.5
# Valkyrie                         200.3
# Name: Gross, Length: 782, dtype: float64

# %%
movies.dtypes
# Out:
# Rank       int64
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
movies["Gross"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 movies["Gross"].mean()
#
# File e:\DT-DS\venv\Lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File e:\DT-DS\venv\Lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# ...

# %%
studios=movies.groupby("Studio")

# %%
type(studios)  #type of the grouped object
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
movies["Studio"].value_counts()
# Out:
# Studio
# Warner Brothers           132
# Buena Vista               125
# Fox                       117
# Universal                 109
# Sony                       86
# Paramount                  76
# Dreamworks                 27
# Lionsgate                  21
# New Line                   16
# MGM                        11
# TriStar                    11
# Miramax                    10
# Weinstein                   6
# Columbia                    5
# WGUSA                       4
# SonR                        2
# Orion                       2
# Polygram                    2
# Dimension                   2
# HC                          1
# China Film Corporation      1
# FUN                         1
# IFC                         1
# FR                          1
# Newmarket                   1
# UTV                         1
# RKO                         1
# GrtIndia                    1
# Artisan                     1
# Pathe                       1
# ...

# %%
studios.count().sort_values(by="Gross", ascending=False)  #count number of movies by Studio and sort by Gross
# Out:
#                         Rank  Gross  Year
# Studio
# Warner Brothers          132    132   132
# Buena Vista              125    125   125
# Fox                      117    117   117
# Universal                109    109   109
# Sony                      86     86    86
# Paramount                 76     76    76
# Dreamworks                27     27    27
# Lionsgate                 21     21    21
# New Line                  16     16    16
# MGM                       11     11    11
# TriStar                   11     11    11
# Miramax                   10     10    10
# Weinstein                  6      6     6
# Columbia                   5      5     5
# WGUSA                      4      4     4
# Dimension                  2      2     2
# Polygram                   2      2     2
# SonR                       2      2     2
# Orion                      2      2     2
# Artisan                    1      1     1
# CL                         1      1     1
# ...

# %%
studios["Gross"].count().sort_values(ascending=False)  #count number of movies by Studio and sort in descending order
# Out:
# Studio
# Warner Brothers           132
# Buena Vista               125
# Fox                       117
# Universal                 109
# Sony                       86
# Paramount                  76
# Dreamworks                 27
# Lionsgate                  21
# New Line                   16
# MGM                        11
# TriStar                    11
# Miramax                    10
# Weinstein                   6
# Columbia                    5
# WGUSA                       4
# Dimension                   2
# Polygram                    2
# SonR                        2
# Orion                       2
# Artisan                     1
# CL                          1
# China Film Corporation      1
# Newmarket                   1
# Lions                       1
# IFC                         1
# FUN                         1
# Focus                       1
# GrtIndia                    1
# HC                          1
# FR                          1
# ...

# %%
studios["Gross"].sum().head()
# Out:
# Studio
# Artisan                                                            $248.60
# Buena Vista               $2,796.30 $2,068.20 $2,048.40 $1,518.80 $1,405...
# CL                                                                 $228.10
# China Film Corporation                                             $699.80
# Columbia                           $306.90 $295.20 $243.20 $215.90 $215.40
# Name: Gross, dtype: object

# %%
studios["Gross"].sum().sort_values(ascending=False)  #sum Gross by Studio and sort in descending order
# Out:
# Studio
# Dreamworks                $919.80 $799.00 $752.60 $746.90 $665.70 $631.7...
# HC                                                                 $870.30
# Lionsgate                 $865.00 $829.70 $755.40 $712.20 $709.70 $698.5...
# China Film Corporation                                             $699.80
# Newmarket                                                          $611.90
# WGUSA                                      $579.20 $259.40 $256.30 $254.20
# TriStar                   $520.90 $352.90 $300.90 $300.40 $297.00 $286.1...
# MGM                       $432.00 $402.40 $361.80 $354.80 $352.20 $351.7...
# Weinstein                  $426.60 $425.40 $414.20 $321.50 $236.40 $233.60
# Orion                                                      $424.20 $272.70
# FR                                                                 $385.30
# IFC                                                                $368.70
# ...
